# %%
# !pip install git+https://github.com/openai/whisper.git
    #to add all dependencies

# %%
import whisper

# %%
model = whisper.load_model("base")

# %%
out = model.transcribe("/content/drive/MyDrive/Projects/OpenAI_Whisper/audio_test.mp3", language="fr")
out
